# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from scipy.ndimage.interpolation import shift
mnist = fetch_openml("mnist_784", version=1, as_frame=False)

# %%
X, y = mnist["data"], mnist["target"]
y = y.astype(np.uint8)
y[0]
# Out:
# numpy.ndarray

# %%
def moving(train_set, train_label):
    direction = [[1, 0], [-1,0], [0, 1], [0, -1]]
    result_set = []
    result_label = []
    for sample, label in zip(train_set, train_label):
        sample = sample.reshape(28, 28)
        for d in direction:
            sample_shifted = shift(sample, d, cval=0)
            result_set.append(sample_shifted.reshape(784))
            result_label.append(label)
    return np.asarray(result_set), np.asarray(result_label)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]

X_train, y_train = moving(X_train, y_train)

# %%
X_train.shape
# Out:
# (240000, 784)

# %%
from sklearn.metrics import accuracy_score

knn_clf=KNeighborsClassifier(n_neighbors=4, weights="distance", n_jobs= 10)
knn_clf.fit(X_train, y_train)
y_predict = knn_clf.predict(X_test)
accuracy_score(y_test, y_predict)
# Out:
# 0.9743

# %%
param_grid = {"n_neighbors":[5,6,7], "weights":["uniform","distance"]}
grid_search = GridSearchCV(knn_clf, param_grid, verbose=4, n_jobs=10, cv = 3, scoring = "accuracy")
grid_search.fit(X_train, y_train)
grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# KNeighborsClassifier(n_jobs=10, n_neighbors=6, weights='distance')
